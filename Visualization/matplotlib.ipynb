# %% [markdown]
# ### What is MATPLOTLIB?
# Matplotlib is a python library used to turn data into charts so we can see patterns, trends, ans problems in our data.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load cleaned data
df = pd.read_csv("../Cleaning_and _working _with_data/Data/processed/cleaned.csv")
print(df)
# Out:
#        Name  Age         Course  Score
# 0     David   18             AI     20
# 1     Sarah   20   Data Science     25
# 2      John   20             AI     30
# 3    Esther   21  Cybersecurity     35
# 4   Unknown   17             AI     45
# 5     Grace   22        Unknown     60
# 6    Daniel   18  Cybersecurity     65
# 7      Ruth   20             AI     70
# 8   Michael   19   Data Science     76
# 9      Anna   20             AI     80
# 10     John   19             AI     91
# 11   Samuel   20   Data Science     87
# 12  Rebecca   22             AI     90
# 13     Paul   23  Cybersecurity     78
# 14     Mary   21   Data Science     82
# 15    Peter   20             AI     90
# 16  Unknown   18             AI     75
# 17    Grace   22   Data Science     90

# %%
# Ploting
plt.plot(df["Age"], df["Score"], marker=0, color="green")
plt.xlabel("Student Name")
plt.ylabel("Student Score")
plt.title("Score Per Student")
df.plot(kind='bar')


plt.show()

# %%
# Highest mean score per age

# %%
# Average Score by Course

course_avg = df.groupby("Course")["Score"].mean()

plt.bar(course_avg.index, course_avg.values)
plt.xlabel("Course")
plt.ylabel("Average Score")¬
plt.title("Average Score by Course")

plt.show()

course_avg
# Out:
# Course
# AI               65.666667
# Cybersecurity    59.333333
# Data Science     72.000000
# Unknown          60.000000
# Name: Score, dtype: float64
