# %% [markdown]
# # Tuples Challenge
#
# 1. Create a tuple with three fruits and print it.
#
# 2. Create a tuple with your name, age, and school, then print the name and school.
#
# 3. Create a tuple with four numbers and print the third number.
#
# 4. Create a tuple of three colors and print the length of the tuple.
#
# 5. Create a tuple with any two items, then print the second item.

# %%
Fruits = ("Apple", "Banana", "Carrot", "Pomengrates")
print(Fruits)
# Out:
# ('Apple', 'Banana', 'Carrot', 'Pomengrates')

# %%
Name = ("David")
Age = (16)
School = ("God's Grace Comprehensive College")
print(Name)
print(School)
# Out:
# David
# God's Grace Comprehensive College

# %%
Numbers = (1, 2, 5, 7, 10)
print(Numbers[3])
# Out:
# 7

# %%
Colours = ("Pink", "Blue", "White", "Red")
print(len(Colours))
# Out:
# 4

# %%
Coding = ("Dictionary", "List")
print(Coding[1])
# Out:
# List
