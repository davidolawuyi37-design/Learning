# %% [markdown]
# 1.Print 50 from:
#
# data = [10, [20, 30, [40, 50]], 60]
#
#
# 2. Remove all "apple" from:
#
# items = ["apple", "banana", "apple", "orange", "apple"]
#
#
# 3. Sum all even numbers in:
#
# nums = [3, 6, 11, 14, 19, 22]
#
#
# 4. Print the middle three from:
#
# letters = ["a", "b", "c", "d", "e", "f", "g"]
#
#
# 5. Insert "Samuel" as 2nd item in:
#
# names = ["John", "Mary", "Paul"]
#
#
# 6. Reverse this list using slicing:
#
# vals = [1, 2, 3, 4, 5]
#
#
# 7. Find the largest number in:
#
# big = [5, [12, 7], 3, [20, 15, 1]]
#
#
# 8. Remove duplicates (keep first appearance):
#
# nums = [4, 2, 4, 5, 2, 8, 8, 8, 1]
#
#
# 9. Combine alternately:
#
# letters = ["a", "b", "c"]
# numbers = [1, 2, 3]
#
#
# 10. Split sentence into words:
#
#
#
# sentence = "Python is super fun"

# %%
Data = [10, [20, 30,[40, 50]], 60]
print(Data[1])
print(Data[1] [2])
print(Data[1] [2] [1])

# %%
Items = ["Apple", "Banana", "Apple", "Orange", "Apple"]
Items = [x for x in Items if x != "Apple"]
print(Items)
# Out:
# ['Banana', 'Orange']

# %%
Numbers = [3, 6, 11, 14, 19, 22]
even_sum = sum(x for x in Numbers if x % 2 == 0)
print(even_sum)
# Out:
# 42

# %%
Letters = ["a", "b", "c", "d", "e", "f", "g"]
middle_letters = Letters[2:5]
print(middle_letters)
# Out:
# ['c', 'd', 'e']

# %%
Names = ["John", "Moses", "Paul"]
Names.insert(1, "Samuel")
print(Names)
# Out:
# ['John', 'Samuel', 'Moses', 'Paul']

# %%
Vals = [1, 2, 3, 4, 5]
reversed_Vals =Vals[::-1]
print(reversed_Vals)
# Out:
# [5, 4, 3, 2, 1]

# %%
Big = [5, [12, 7], 3 , [20, 15, 1]]
largest = max(
    5,
    max([12, 7]),
    3,
    max([20, 15, 1])
)
print(largest)
# Out:
# 20

# %%
Numbers = [4, 2, 4, 5, 2, 8, 8, 8, 1]

Unique_nums = []
for Number in Numbers:
    if Number not in Unique_nums:
        Unique_nums.append (Number)

print(Unique_nums)

# %%
Letters = ["a", "b", "c"]
Numbers = [1, 2. 3]
Combined = []
for l, n in zip(Letters, Numbers):
    Combined.append(l)
    Combined.append(n)
print(Combined)

# %%
Sentence = "Python is super fun"
Words = Sentence.split()
print(Words)
