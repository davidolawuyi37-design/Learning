# %% [markdown]
# What is a List?
#
# A list is a collection of items stored in one variable.

# %% [markdown]
# Creating a List

# %%
fruits = ["apple", "bannana", "oranges"]
numbers = [10, 20, 30]
mixed = ["David", 10, True]

print(fruits)
print(numbers)
print(mixed)
# Out:
# ['apple', 'bannana', 'oranges']
# [10, 20, 30]
# ['David', 10, True]

# %% [markdown]
# Accessing Items

# %%
print(fruits[0])
print(numbers[2])
print(f"{mixed[0]} is a smart student and this is {mixed[2]}")
# Out:
# apple
# 30
# David is a smart student and this is True

# %% [markdown]
# Changing Items

# %%
mixed[0] = "Divine"
print(mixed[0])
print(mixed)
print(f"{mixed[0]} is a smart student and this is {mixed[2]}")
# Out:
# Divine
# ['Divine', 10, True]
# Divine is a smart student and this is True

# %% [markdown]
# Adding Items

# %%
mixed.append("Sam")
print(mixed)

mixed.insert(1, "David")
print(mixed)
# Out:
# ['Divine', 10, True, 'Sam']
# ['Divine', 'David', 10, True, 'Sam']

# %% [markdown]
# Removing Items

# %%
mixed.remove("Divine")
print(mixed)

mixed.pop()
print(mixed)
# Out:
# ['David', 10, True, 'Sam']
# ['David', 10, True]

# %% [markdown]
# Your Turn - Exercise
#
# Redo all the above in your own way.

# %%
Name = ["David", "Francisca", "Priscilla","Glory","Grace","Divine"]
African_Countries = ["Nigeria", "Ivory Coast","Cameroon","Gabon","Ghana","Senegal"]
Colours = ["Red", "Blue", "Pink", "Green", "White", "Grey"]

print(Name)
print(African_Countries)
print(Colours)
# Out:
# ['David', 'Francisca', 'Priscilla', 'Glory', 'Grace', 'Divine']
# ['Nigeria', 'Ivory Coast', 'Cameroon', 'Gabon', 'Ghana', 'Senegal']
# ['Red', 'Blue', 'Pink', 'Green', 'White', 'Grey']

# %% [markdown]
# Acessing Items

# %%
print(Name[1])
print(African_Countries[0])
print(Colours[1])
print(f"Her name is {Name[1]}, she is from {African_Countries[0]}, and her best colour is {Colours[1]}")
# Out:
# Francisca
# Nigeria
# Blue
# Her name is Francisca, she is from Nigeria, and her best colour is Blue

# %%
Name[0] = "Favour"
print(Name[0])
print(f"Her name is {Name[0]}, she is from {African_Countries[0]}, and her best colour is {Colours[1]}")
# Out:
# Favour
# Her name is Favour, she is from Nigeria, and her best colour is Blue

# %%
Name.append("Faith")
print(Name)

Name.insert(0, "Flourish")
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Name.append("Faith")
#       2 print(Name)
#       4 Name.insert(0, "Flourish")
#
# NameError: name 'Name' is not defined

# %%
Name.remove("Flourish")
print(Name)

Name.pop()
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Name.remove("Flourish")
#       2 print(Name)
#       4 Name.pop()
#
# NameError: name 'Name' is not defined
