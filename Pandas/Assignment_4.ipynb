# %%
import pandas as pd

data = {
    "Name": [
        "David","Sarah","John","Esther","Michael","Grace","Daniel","Ruth","Samuel","Deborah",
        "Paul","Mary","Peter","Anna","Joseph","Rebecca","James","Hannah","Andrew","Lydia",
        "Stephen","Naomi","Philip","Rachel","Simon","Martha","Timothy","Abigail","Luke","Joy",
        "Nathan","Faith","Mark","Clara","Isaac","Hope","Barnabas","Eunice","Joel","Mercy",
        "Caleb","Irene","Silas","Patience","Elijah","Victoria","Aaron","Peace","Joshua","Favour",
        "Noah","Blessing","Matthew","Charity","Jacob","Wisdom","Benjamin","Comfort","Daniel2","Praise",
        "David2","Grace2","John2","Esther2","Michael2","Sarah2","Paul2","Mary2","Peter2","Anna2",
        "Joseph2","Rebecca2","James2","Hannah2","Andrew2","Lydia2","Samuel2","Deborah2","Ruth2","Daniel3"
    ],

    "Age": [
        18,20,19,21,17,22,18,20,23,19,
        21,18,22,20,19,23,18,21,22,20,
        24,19,21,22,20,18,23,19,21,20,
        22,18,24,19,21,20,23,18,22,19,
        21,20,22,18,24,19,21,20,23,18,
        22,19,21,20,23,18,24,19,22,20,
        21,19,23,18,22,20,24,19,21,18,
        23,20,22,19,24,18,21,20,22,19
    ],

    "Course": [
        "AI","Data Science","AI","Cybersecurity","AI","Data Science","Cybersecurity","AI","Data Science","AI",
        "AI","Cybersecurity","Data Science","AI","AI","Data Science","Cybersecurity","AI","Data Science","AI",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science",
        "Cybersecurity","AI","Data Science","AI","AI","Cybersecurity","Data Science","AI","AI","Data Science"
    ],

    "Score": [
        85,78,92,69,88,90,74,81,86,79,
        91,67,84,88,76,93,70,82,89,80,
        65,87,90,78,83,72,88,91,77,85,
        69,92,86,74,90,81,68,89,84,76,
        93,80,87,71,95,78,82,90,75,88,
        66,91,85,79,94,72,83,89,77,86,
        70,92,84,76,88,81,67,90,85,73,
        93,79,87,74,91,68,82,88,80,75
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
# Exception ignored in PyObject_HasAttr(); consider using PyObject_HasAttrWithError(), PyObject_GetOptionalAttr() or PyObject_GetAttr():
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# AttributeError: partially initialized module 'pandas' from 'c:\Users\USER\OneDrive\Desktop\Learning\.venv\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       3 data = {
#       4     "Name": [
#       5         "David","Sarah","John","Esther","Michael","Grace","Daniel","Ruth","Samuel","Deborah",
#    (...)     46     ]
#      47 }
#      49 df = pd.DataFrame(data)
#
# File c:\Users\USER\OneDrive\Desktop\Learning\.venv\Lib\site-packages\pandas\__init__.py:151
#     133 from pandas.core.reshape.api import (
#     134     concat,
#     135     lreshape,
#    (...)    147     qcut,
#     148 )
#     150 from pandas import api, arrays, errors, io, plotting, tseries
# --> 151 from pandas import testing
#     152 from pandas.util._print_versions import show_versions
#     154 from pandas.io.api import (
#     155     # excel
#     156     ExcelFile,
#    (...)    184     read_spss,
#     185 )
#
# File c:\Users\USER\OneDrive\Desktop\Learning\.venv\Lib\site-packages\pandas\testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File c:\Users\USER\OneDrive\Desktop\Learning\.venv\Lib\site-packages\pandas\_testing\__init__.py:405
#     400     import pytest
#     402     return pytest.raises(expected_exception, match=None)
# --> 405 cython_table = pd.core.common._cython_table.items()
#     408 def get_cython_table_params(ndframe, func_names_and_expected):
#     409     """
#     410     Combine frame, functions from com._cython_table
#     411     keys and expected result.
#    (...)    423         List of three items (DataFrame, function, expected result)
#     424     """
#
# AttributeError: partially initialized module 'pandas' from 'c:\Users\USER\OneDrive\Desktop\Learning\.venv\Lib\site-packages\pandas\__init__.py' has no attribute 'core' (most likely due to a circular import)

# %% [markdown]
# #### Modify the above data:
# 1. Create two new columns; passed and matured and set their values to be score > 50 and age > 18 respectively
# 2. Filter the data frame to only contain passed students.
# 3.  Filter the data frame to only contain matured students.
# 4.  Filter the data frame to only contain matured students and passed students.
# 5.  Filter the data frame to only contain matured students and failed students.

# %%
df["Passed"] = df["Score"] > 50
df["Matured"] = df["Age"] > 18

print(df)
# Out:
#         Name  Age         Course  Score  Passed  Matured
# 0      David   18             AI     85    True    False
# 1      Sarah   20   Data Science     78    True     True
# 2       John   19             AI     92    True     True
# 3     Esther   21  Cybersecurity     69    True     True
# 4    Michael   17             AI     88    True    False
# ..       ...  ...            ...    ...     ...      ...
# 75    Lydia2   18  Cybersecurity     68    True    False
# 76   Samuel2   21   Data Science     82    True     True
# 77  Deborah2   20             AI     88    True     True
# 78     Ruth2   22             AI     80    True     True
# 79   Daniel3   19   Data Science     75    True     True
#
# [80 rows x 6 columns]

# %%
Passed_students = df[["Passed"]]
print(Passed_students)
# Out:
#     Passed
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
#
# [80 rows x 1 columns]

# %%
Matured_students = df[["Matured"]]
print(Matured_students)
# Out:
#     Matured
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# ..      ...
# 75    False
# 76     True
# 77     True
# 78     True
# 79     True
#
# [80 rows x 1 columns]

# %%
Passed_Matured_students = df[["Passed", "Matured"]]
print(Passed_Matured_students)
# Out:
#     Passed  Matured
# 0     True    False
# 1     True     True
# 2     True     True
# 3     True     True
# 4     True    False
# ..     ...      ...
# 75    True    False
# 76    True     True
# 77    True     True
# 78    True     True
# 79    True     True
#
# [80 rows x 2 columns]

# %%
Matured_Failed_students = df[df["Matured"] == True] &  df[df["Passed"] == False]
print(Matured_Failed_students)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Matured_Failed_students = df[df["Matured"] == True] &  df[df["Passed"] == False]
#       2 print(Matured_Failed_students)
#
# NameError: name 'df' is not defined
