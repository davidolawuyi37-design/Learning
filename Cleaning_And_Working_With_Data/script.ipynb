# %%
import pandas as pd

# %%
df = pd.read_csv("Data/hop.csv")
print(df)
# Out:
#               Name  Age            Course    Score
# 0            David   18  Computer Science       85
# 1            Aisha   17       Mathematics       92
# 2           Samuel   19           Physics       78
# 3         Blessing   18         Chemistry       88
# 4          Michael   20       Engineering       90
# 5           Daniel   18        Statistics       74
# 6            Faith   17           Biology       81
# 7           Joshua   19  Computer Science       89
# 8           Esther   18       Mathematics       95
# 9         Emmanuel   20           Physics       67
# 10           Grace   17         Chemistry       84
# 11          Joseph   19       Engineering       91
# 12         Deborah   18           Biology       76
# 13         Ibrahim   20        Statistics       88
# 14            Ruth   17  Computer Science       93
# 15           Peter   19       Mathematics       70
# 16           Sarah   18           Physics       86
# ...
