# %% [markdown]
# ## Dictionaries

# %% [markdown]
# ### What is a Dictionary

# %% [markdown]
# A dictionary stores data in key value pairs.
# Keys must be unique.

# %% [markdown]
# ### Creating a Dictionary

# %%
student = {
    "Name": "Joy",
    "Age": 16,
    "Gender": "Female"
}

print(student)
# Out:
# {'Name': 'Joy', 'Age': 16, 'Gender': 'Female'}

# %% [markdown]
# Accessing Values

# %%
print(student["Name"])
# Out:
# Joy
