# %%
Students = [
    {"Name": "David", "Age": 15}, 
    ["ball", "meat", "dance", "Joy"],
    "James",
    30,
    {"Name": "Joy", "Age": 16}, 
    {"Name": "Shola", "Age": 17}
]
print(Students[2])
# Out:
# James

# %%
print(Students[1][1])
# Out:
# meat
