# %%
Students = [
    {"Name": "David", "Age": 15}, 
    ["ball", "meat", "dance", "Joy"],
    "James",
    30,
    {"Name": "Joy", "Age": 16}, 
    {"Name": "Shola", "Age": 17}
]
print(Students[2])
# Out:
# James

# %%
print(Students[4]["Name"])  
# Accessing and printing specific elements from the Students list
print(Students[0]["Age"])
print(Students[5]["Name"])
print(Students[1][3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(Students[4]["Name"])
#       2 # Accessing and printing specific elements from the Students list
#       3 print(Students[0]["Age"])
#
# NameError: name 'Students' is not defined
