# %%
Students = [
    {"Name": "David", "Age": 15 },
    {"Name": "Joy", "Age": 16},
    {"Name": "Shola", "Age": 17}
]
print(Students)
# Out:
# [{'Name': 'David', 'Age': 15}, {'Name': 'Joy', 'Age': 16}, {'Name': 'Shola', 'Age': 17}]

# %%
print(Students{
    [0][1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(Students[0][1])
#
# NameError: name 'Students' is not defined
