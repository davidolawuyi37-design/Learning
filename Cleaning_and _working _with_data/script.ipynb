# %%
import pandas as pd

# %%
df = pd.read_csv("Data/raw/raw.csv")
print(df)
# Out:
#                           Name              Age Course                   Score
# 0                                 David      18                       AI    85
# 1                                  sarah     20             data science   NaN
# 2                                   JOHN    NaN                      AI     92
# 3                                 Esther     21            Cybersecurity    69
# 4                                    NaN     17                       AI    88
# 5                                  Grace     22                      NaN    90
# 6                                 Daniel     18            Cybersecurity   NaN
# 7                                 Daniel  18               Cybersecurity   NaN
# 8                                   Ruth    NaN                       ai    81
# 9                                Michael     19             Data Science    76
# 10                                 ANNA      20                       AI    89
# ...

# %%
df.columns
# Out:
# Index(['                       Name          ', 'Age',
#        'Course                  ', 'Score'],
#       dtype='object')
