# %%
# we want group different houses and their prices  into 2 clusters:
# expensive houses
# cheap houses

import pandas as pd
from sklearn.cluster import KMeans
data = {
    "home_type": ["Apartment", "Apartment", "Apartment", "Apartment", "Apartment", "Apartment",
                  "Bungalow", "Bungalow", "Bungalow", "Bungalow", "Bungalow", "Bungalow",
                  "Duplex", "Duplex", "Duplex", "Duplex", "Duplex", "Duplex",
                  "Detached_House", "Detached_House", "Detached_House", "Detached_House", "Detached_House", "Detached_House",
                  "Villa", "Villa", "Villa", "Villa", "Villa", "Villa"],

    "size_sqft": [400, 500, 550, 600, 650, 700, 900, 1000, 1100, 1200, 1300, 1400,
                  1600, 1700, 1800, 1900, 2000, 2100, 2300, 2500, 2700, 2900, 3100, 3300,
                  3600, 4000, 4300, 4600, 5000, 5400],

    "bedrooms": [1, 1, 2, 2, 2, 3, 2, 2, 3, 3, 3, 4,
                 3, 3, 4, 4, 4, 5, 4, 4, 5, 5, 5, 6,
                 5, 6, 6, 7, 7, 8],

    "price": [35000, 40000, 45000, 50000, 55000, 60000, 70000, 80000, 90000, 100000, 110000, 120000,
              150000, 170000, 190000, 210000, 230000, 250000, 300000, 330000, 360000, 390000, 420000, 450000,
              520000, 580000, 640000, 700000, 780000, 850000]
}

df = pd.DataFrame(data)
#print(df)

x = df[["size_sqft", "bedrooms", "price"]]

modelling = KMeans(n_clusters=3)
modelling.fit(x)

df["cluster"] = modelling.labels_
print(df)
# Out:
#          home_type  size_sqft  bedrooms   price  cluster
# 0        Apartment        400         1   35000        2
# 1        Apartment        500         1   40000        2
# 2        Apartment        550         2   45000        2
# 3        Apartment        600         2   50000        2
# 4        Apartment        650         2   55000        2
# 5        Apartment        700         3   60000        2
# 6         Bungalow        900         2   70000        2
# 7         Bungalow       1000         2   80000        2
# 8         Bungalow       1100         3   90000        2
# 9         Bungalow       1200         3  100000        2
# 10        Bungalow       1300         3  110000        2
# 11        Bungalow       1400         4  120000        2
# 12          Duplex       1600         3  150000        2
# 13          Duplex       1700         3  170000        2
# 14          Duplex       1800         4  190000        2
# 15          Duplex       1900         4  210000        0
# 16          Duplex       2000         4  230000        0
# 17          Duplex       2100         5  250000        0
# 18  Detached_House       2300         4  300000        0
# 19  Detached_House       2500         4  330000        0
# 20  Detached_House       2700         5  360000        0
# 21  Detached_House       2900         5  390000        0
# 22  Detached_House       3100         5  420000        0
# 23  Detached_House       3300         6  450000        0
# 24           Villa       3600         5  520000        1
# 25           Villa       4000         6  580000        1
# 26           Villa       4300         6  640000        1
# 27           Villa       4600         7  700000        1
# 28           Villa       5000         7  780000        1
# 29           Villa       5400         8  850000        1

# %%
# Visuslize clusters
import matplotlib.pyplot as plt
plt.scatter(df['size_sqft'], df["price"], c=df["cluster"])
plt.xlabel("size_sqft")
plt.ylabel("price")
plt.title("Price and Sqr_Ft")
plt.show()

# %%
# we want group students performance into 3 clusters:
# High performers
# MediumKMeans performance
# Low performance

import pandas as pd
from sklearn.cluster import KMeans

data = {
    "hours_studied": [1,2,3,4,5,6,7,8,2,6,4,7],
    "exam_score": [40,50,55,60,65,70,80,90,48,75,62,85]
}

df = pd.DataFrame(data)
print(df)

x  = df[["hours_studied", "exam_score"]]

model = KMeans(n_clusters=5)
model.fit(x)

df["cluster"] = model.labels_
print(df)
# Out:
#     hours_studied  exam_score
# 0               1          40
# 1               2          50
# 2               3          55
# 3               4          60
# 4               5          65
# 5               6          70
# 6               7          80
# 7               8          90
# 8               2          48
# 9               6          75
# 10              4          62
# 11              7          85
#     hours_studied  exam_score  cluster
# 0               1          40        0
# 1               2          50        0
# 2               3          55        0
# 3               4          60        2
# 4               5          65        2
# 5               6          70        2
# 6               7          80        1
# 7               8          90        1
# 8               2          48        0
# 9               6          75        1
# 10              4          62        2
# 11              7          85        1

# %%
# Visuslize clusters
import matplotlib.pyplot as plt
plt.scatter(df['hours_studied'], df["exam_score"], c=df["cluster"])
plt.xlabel("hours_studied")
plt.ylabel("exam_score")
plt.title("hours_studied and exam_score")
plt.show()
