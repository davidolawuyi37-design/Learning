# %% [markdown]
# ### AI MACHINE LEARNING
# AI means Artificial Intelligence.
# AI is making machines behave intelligently like humans.
# E.G : Voice assistant, Face recognition, e.t.c.

# %% [markdown]
# ### What is machine learning?
# When computers learn patterns from data instead of being programmed step by step.

# %% [markdown]
# ### Two types of machine learning
# 1. The supervised learning: Predicting.
# 2. The unsupervised learning: Finding patterns.

# %% [markdown]
# ## Supervised Learning
#
# #### There are two major kinds of Machine learning Algorithm:
# 1. Regression
# 2. Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import IinnearRegrssion
import pandas as pd

df = pd.read_csv("cleand.csv")

df
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.linear_model import IinnearRegrssion
#       3 import pandas as pd
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)    111     "compose",
#     112 ]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:14
#      11 import warnings
#      12 from collections import defaultdict
# ---> 14 import numpy as np
#      16 from sklearn import __version__
#      17 from sklearn._config import config_context, get_config
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py:125
#     122 from . import _distributor_init
#     124 try:
# --> 125     from numpy.__config__ import show_config
#     126 except ImportError as e:
#     127     msg = """Error importing numpy: you should not try to import numpy from
#     128     its source directory; please exit the numpy source tree, and relaunch
#     129     your python interpreter from there."""
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\__init__.py:22
#      19         env_added.append(envkey)
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#      24     import sys
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\multiarray.py:11
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)      6
#       7 """
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#      14 # These imports are needed for backward compatibility,
#      15 # do not change them. issue gh-15518
#      16 # _get_ndarray_c_version is semi-public, on purpose not added to __all__
#
# RuntimeError: CPU dispatcher tracer already initlized
