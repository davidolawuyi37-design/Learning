# %% [markdown]
# ### AI MACHINE LEARNING
# AI means Artificial Intelligence.
# AI is making machines behave intelligently like humans.
# E.G : Voice assistant, Face recognition, e.t.c.

# %% [markdown]
# ### What is machine learning?
# When computers learn patterns from data instead of being programmed step by step.

# %% [markdown]
# ### Two types of machine learning
# 1. The supervised learning: Predicting.
# 2. The unsupervised learning: Finding patterns.

# %% [markdown]
# ## Supervised Learning
#
# #### There are two major kinds of Machine learning Algorithm:
# 1. Regression
# 2. Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd

df = pd.read_csv("cd.csv")
# To be used for classification.
print(df)
# Out:
#        Name  Age         Course  Score
# 0     David   18             AI     20
# 1     Sarah   20   Data Science     25
# 2      John   20             AI     30
# 3    Esther   21  Cybersecurity     35
# 4   Unknown   17             AI     45
# 5     Grace   22        Unknown     60
# 6    Daniel   18  Cybersecurity     65
# 7      Ruth   20             AI     70
# 8   Michael   19   Data Science     76
# 9      Anna   20             AI     80
# 10     John   19             AI     91
# 11   Samuel   20   Data Science     87
# 12  Rebecca   22             AI     90
# 13     Paul   23  Cybersecurity     78
# 14     Mary   21   Data Science     82
# 15    Peter   20             AI     90
# 16  Unknown   18             AI     75
# 17    Grace   22   Data Science     90
